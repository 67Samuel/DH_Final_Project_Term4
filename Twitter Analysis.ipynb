# %%
import nltk
import pandas as pd
from IPython.display import display
nltk.download('vader_lexicon')
nltk.download('punkt')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
sid = SentimentIntensityAnalyzer()
from nltk.stem import WordNetLemmatizer
wordnet_lemmatizer = WordNetLemmatizer()
from nltk.corpus import stopwords
pd.set_option('display.max_colwidth', None)
stop_words = stopwords.words("english")
pd.set_option("max_rows", None)
import itertools
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
def reformat_data(df):
    list_df = []
    for i, row in df.iterrows():
        row_list = str(row).strip(f'Name: {i}, dtype: object').strip('Field1').strip('\n').strip(' ').split('\\n')
        if len(row_list) < 5:
            continue
        if row_list[4] == 'Replying to ':
            continue
        while '' in row_list:
            row_list.remove('')
        del row_list[0] #delete name (we're using the handle)
        del row_list[1] #delete dot
        end = -1
        for i in (-3, -2, -1):
            if (row_list[i].isnumeric()):
                end = i
                break
        content_list = row_list[2:end]
        content = ''.join(i for i in content_list)
        done_list = row_list[:2]+row_list[end:]+[None]*(end+3)+[content]
        if len(done_list[1]) < 8: #if there is no year
            done_list[1] += ' 2020'
        while len(done_list) < 6:
            done_list.insert(-2, None)
        list_df.append(done_list)
    return list_df

# %%
list_df = reformat_data(df)

# %%
main_df = pd.DataFrame(list_df, columns=["Name", "Date", "Num_comments", "Num_retweets", "Num_likes", "Content"])

# %%
#define function that applies sid and returns the compound score
def analyse(text):
    scores = sid.polarity_scores(text)
    return scores["compound"]

# %%
VADER_compound_score_list = []
for text in main_df["Content"]:
    VADER_compound_score_list.append(analyse(text))

# %%
#VADER was made as a sentiment analysis tool. we can use it to filter out possible heresy/non chrisitan posts
main_df["VADER_score"] = VADER_compound_score_list

# %%
def get_adjectives_dict(df, stop_words):
    lemmed_adj_dict = {}
    #original_adj_dict = {}
    for sentence in df["Content"]:
        tokens = nltk.word_tokenize(sentence)
        lemmed_tokens = []
        for token in tokens:
            if token not in stop_words:
                lemmed_tokens.append(wordnet_lemmatizer.lemmatize(token))
        lemmed_tagged = nltk.pos_tag(lemmed_tokens)
        #original_tagged = nltk.pos_tag(tokens)
        for tag_set in lemmed_tagged:
            if 'JJ' in tag_set[1]:
                adj = ''.join([i for i in tag_set[0] if i.isalpha()])
                if adj not in lemmed_adj_dict:
                    lemmed_adj_dict[adj] = 1
                else:
                    lemmed_adj_dict[adj] += 1
    lemmed_adj_sorted_dict = {}
    lemmed_adj_sorted_keys = sorted(lemmed_adj_dict, key=lemmed_adj_dict.get, reverse=True)
    for w in lemmed_adj_sorted_keys:
        lemmed_adj_sorted_dict[w] = lemmed_adj_dict[w]
    del lemmed_adj_sorted_dict['']
    return lemmed_adj_sorted_dict

# %%
#this shows the adjectives and freq of appearance in posts containing the word jesus for this corpus
lemmed_adj_sorted_dict = get_adjectives_dict(main_df, stop_words)
lemmed_adj_sorted_dict
# Out:
# {'u': 123,
#  'good': 31,
#  'unto': 24,
#  'give': 20,
#  'many': 18,
#  'new': 18,
#  'eternal': 17,
#  'great': 16,
#  'dead': 15,
#  'true': 14,
#  'Good': 12,
#  'able': 11,
#  'hear': 11,
#  'much': 10,
#  'understanding': 10,
#  'last': 10,
#  'Christian': 10,
#  'better': 10,
#  'guard': 9,
#  'live': 9,
#  'perfect': 9,
#  'separate': 9,
#  'thy': 9,
#  'present': 8,
#  'right': 8,
#  'free': 8,
#  'beautiful': 8,
#  'open': 8,
#  'strong': 8,
#  'possible': 8,
#  'impossible': 8,
#  'best': 8,
#  'anxious': 7,
#  'ready': 7,
#  'white': 7,
#  'happy': 7,
#  'human': 7,
#  'Happy': 7,
#  'little': 7,
#  'first': 7,
#  'second': 7,
#  'pray': 7,
#  'faith': 7,
#  'glorious': 7,
#  'whole': 7,
#  'precious': 7,
#  'full': 6,
#  'light': 6,
#  'disciple': 6,
#  'know': 6,
#  'faithful': 6,
#  'else': 5,
#  'wonderful': 5,
#  'old': 5,
#  'high': 5,
#  'bad': 5,
#  'guilty': 5,
#  'sin': 5,
#  'different': 5,
#  'flesh': 5,
#  'gospel': 5,
#  'touch': 5,
#  'worthy': 5,
#  'thou': 5,
#  'belong': 4,
#  'angel': 4,
#  'request': 4,
#  'enough': 4,
#  'worship': 4,
#  'glory': 4,
#  'Most': 4,
#  'real': 4,
#  'lead': 4,
#  'physical': 4,
#  'broken': 4,
#  'favorite': 4,
#  'amazing': 4,
#  'follow': 4,
#  'earth': 4,
#  'financial': 4,
#  'hard': 4,
#  'next': 4,
#  'grateful': 4,
#  'single': 4,
#  'you': 4,
#  'righteous': 4,
#  'child': 4,
#  'powerful': 4,
#  'ur': 4,
#  'willing': 3,
#  'ta': 3,
#  'mean': 3,
#  'ask': 3,
#  'supernatural': 3,
#  'future': 3,
#  'thank': 3,
#  'alive': 3,
#  'mercy': 3,
#  'deep': 3,
#  'weary': 3,
#  'personal': 3,
#  'tear': 3,
#  'lower': 3,
#  'oh': 3,
#  'total': 3,
#  'half': 3,
#  'greatest': 3,
#  'sovereign': 3,
#  'need': 3,
#  'heavy': 3,
#  'divine': 3,
#  'fast': 3,
#  'rich': 3,
#  'cross': 3,
#  'moral': 3,
#  'spiritual': 3,
#  'afraid': 3,
#  'direct': 3,
#  'name': 3,
#  'Dear': 3,
#  'w': 3,
#  'dear': 3,
#  'savior': 3,
#  'clean': 3,
#  'everyday': 3,
#  'soul': 3,
#  'certain': 3,
#  'Bible': 3,
#  'Christ': 3,
#  'parable': 3,
#  'sick': 3,
#  'trust': 3,
#  'sinful': 2,
#  'thankful': 2,
#  'height': 2,
#  'deaf': 2,
#  'potential': 2,
#  'Genuine': 2,
#  'evil': 2,
#  'renew': 2,
#  'repent': 2,
#  'higher': 2,
#  'them': 2,
#  'love': 2,
#  'GOOD': 2,
#  'several': 2,
#  'forgive': 2,
#  'purpose': 2,
#  'excellent': 2,
#  'excited': 2,
#  'seventh': 2,
#  'wish': 2,
#  'album': 2,
#  'dark': 2,
#  'accept': 2,
#  'save': 2,
#  'daily': 2,
#  'imaginary': 2,
#  'seek': 2,
#  'Last': 2,
#  'come': 2,
#  'aware': 2,
#  'worry': 2,
#  'find': 2,
#  'awesome': 2,
#  'green': 2,
#  'path': 2,
#  'weak': 2,
#  'religious': 2,
#  'sure': 2,
#  'read': 2,
#  'social': 2,
#  'important': 2,
#  'careful': 2,
#  'mental': 2,
#  'blameless': 2,
#  'unique': 2,
#  'Timothy': 2,
#  'healthy': 2,
#  'bigger': 2,
#  'lot': 2,
#  'pillar': 2,
#  'fisher': 2,
#  'special': 2,
#  'recent': 2,
#  'bible': 2,
#  'make': 2,
#  'terrible': 2,
#  'We': 2,
#  'sexual': 2,
#  'longer': 2,
#  'kingdom': 2,
#  'stablish': 2,
#  'sleep': 2,
#  'entire': 2,
#  'complete': 2,
#  'Particular': 2,
#  'gracious': 2,
#  'the': 2,
#  'guide': 2,
#  'difficult': 2,
#  'painful': 2,
#  'bless': 2,
#  'catholic': 2,
#  'want': 2,
#  'sacrificial': 2,
#  'crazy': 2,
#  'le': 2,
#  'follower': 2,
#  'available': 2,
#  'struggle': 2,
#  'big': 2,
#  'remarkable': 2,
#  'hit': 2,
#  'calm': 2,
#  'holy': 2,
#  'bc': 2,
#  'demonic': 2,
#  'double': 2,
#  'advent': 2,
#  'worth': 2,
#  'joyous': 2,
#  'common': 2,
#  'greatness': 2,
#  'unknown': 2,
#  'prayer': 2,
#  'step': 2,
#  'net': 2,
#  'receive': 2,
#  'sweet': 2,
#  'poor': 2,
#  'false': 2,
#  'solitary': 2,
#  'heal': 2,
#  'clear': 2,
#  'innocent': 2,
#  'skill': 2,
#  'ordinary': 2,
#  'manifest': 2,
#  'accordingly': 2,
#  'internal': 2,
#  'let': 1,
#  'thru': 1,
#  'meup': 1,
#  'debate': 1,
#  'advocate': 1,
#  'battleFear': 1,
#  'upEven': 1,
#  'inA': 1,
#  'freeNo': 1,
#  'stir': 1,
#  'late': 1,
#  'uncomfortableAnd': 1,
#  'prodigal': 1,
#  'length': 1,
#  'brief': 1,
#  'itThen': 1,
#  'heshe': 1,
#  'simple': 1,
#  'ig': 1,
#  'soundcloud': 1,
#  'final': 1,
#  'irreversible': 1,
#  'carry': 1,
#  'living': 1,
#  'end': 1,
#  'mere': 1,
#  'selective': 1,
#  'entered': 1,
#  'saith': 1,
#  'red': 1,
#  'Close': 1,
#  'empower': 1,
#  'anoint': 1,
#  'lust': 1,
#  'primary': 1,
#  'apostle': 1,
#  'evangelist': 1,
#  'fellowcitizens': 1,
#  'prophet': 1,
#  'cornerstone': 1,
#  'giant': 1,
#  'corrupt': 1,
#  'dim': 1,
#  'major': 1,
#  'depth': 1,
#  'sword': 1,
#  'unforeseen': 1,
#  'seventyseven': 1,
#  'protect': 1,
#  'safe': 1,
#  'past': 1,
#  'amazed': 1,
#  'chief': 1,
#  'hart': 1,
#  'panteth': 1,
#  'die': 1,
#  'thessalonian': 1,
#  'LORD': 1,
#  'lean': 1,
#  'diligent': 1,
#  'Lots': 1,
#  'allLord': 1,
#  'affection': 1,
#  'Little': 1,
#  'threadIn': 1,
#  'boy': 1,
#  'satisfy': 1,
#  'heartshaped': 1,
#  'wrongJohn': 1,
#  'separated': 1,
#  'lisasharper': 1,
#  'thisWe': 1,
#  'allhisHorrible': 1,
#  'fulfillment': 1,
#  'tremble': 1,
#  'Satanic': 1,
#  'break': 1,
#  'nameYour': 1,
#  'expect': 1,
#  'sound': 1,
#  'needed': 1,
#  'isDear': 1,
#  'spirit': 1,
#  'kanyewest': 1,
#  'Eucharistic': 1,
#  'perish': 1,
#  'shame': 1,
#  'lastnight': 1,
#  'teenager': 1,
#  'crush': 1,
#  'mind': 1,
#  'bridle': 1,
#  'uncomfortable': 1,
#  'learn': 1,
#  'flexible': 1,
#  'liver': 1,
#  'unusual': 1,
#  'ample': 1,
#  'hermeneutical': 1,
#  'see': 1,
#  'understand': 1,
#  'invisible': 1,
#  'earthvisible': 1,
#  'quick': 1,
#  'ab': 1,
#  'nectar': 1,
#  'unprofitable': 1,
#  'strategic': 1,
#  'alignment': 1,
#  'intercept': 1,
#  'vicky': 1,
#  'father': 1,
#  'filthy': 1,
#  'wicked': 1,
#  'accountable': 1,
#  'covenant': 1,
#  'worthily': 1,
#  'stan': 1,
#  'bother': 1,
#  'necessary': 1,
#  'secure': 1,
#  'stressful': 1,
#  'avoid': 1,
#  'lazy': 1,
#  'ONLY': 1,
#  'exact': 1,
#  'act': 1,
#  'expert': 1,
#  'cultural': 1,
#  'youYou': 1,
#  'attacked': 1,
#  'realityMay': 1,
#  'forwardEzekiel': 1,
#  'hold': 1,
#  'please': 1,
#  'conservative': 1,
#  'endorsement': 1,
#  'historian': 1,
#  'hot': 1,
#  'essential': 1,
#  'midst': 1,
#  'lyric': 1,
#  'homiletical': 1,
#  'reverse': 1,
#  'airborne': 1,
#  'lately': 1,
#  'win': 1,
#  'toIn': 1,
#  'kept': 1,
#  'set': 1,
#  'favour': 1,
#  'Do': 1,
#  'breath': 1,
#  'shenanigan': 1,
#  'online': 1,
#  'tweet': 1,
#  'temporal': 1,
#  'upon': 1,
#  'goodness': 1,
#  'negative': 1,
#  'confident': 1,
#  'sparrow': 1,
#  'hair': 1,
#  'highest': 1,
#  'notice': 1,
#  'us': 1,
#  'mum': 1,
#  'Name': 1,
#  'door': 1,
#  'fruitful': 1,
#  'understood': 1,
#  'critical': 1,
#  'psalm': 1,
#  'He': 1,
#  'dried': 1,
#  'afresh': 1,
#  'Advent': 1,
#  'celebrate': 1,
#  'allconquering': 1,
#  'public': 1,
#  'cloth': 1,
#  'become': 1,
#  'YOUR': 1,
#  'church': 1,
#  'soften': 1,
#  'fresh': 1,
#  'stale': 1,
#  'well': 1,
#  'moment': 1,
#  'rough': 1,
#  'fisherman': 1,
#  'distant': 1,
#  'individual': 1,
#  'praise': 1,
#  'seen': 1,
#  'believe': 1,
#  'darkness': 1,
#  'MORE': 1,
#  'THAN': 1,
#  'doomed': 1,
#  'liberal': 1,
#  'central': 1,
#  'foundational': 1,
#  'elosisofficial': 1,
#  'belize': 1,
#  'political': 1,
#  'ethnic': 1,
#  'economic': 1,
#  'picshure': 1,
#  'sown': 1,
#  'smallest': 1,
#  'largest': 1,
#  'wilderness': 1,
#  'stronger': 1,
#  'wiser': 1,
#  'prepared': 1,
#  'Precious': 1,
#  'await': 1,
#  'honorable': 1,
#  'goOf': 1,
#  'immoralNo': 1,
#  'Many': 1,
#  'justified': 1,
#  'nameSay': 1,
#  'Latterday': 1,
#  'undeviating': 1,
#  'intimate': 1,
#  'Your': 1,
#  'saw': 1,
#  'Open': 1,
#  'genuine': 1,
#  'jealous': 1,
#  'imagine': 1,
#  'build': 1,
#  'proper': 1,
#  'stable': 1,
#  'worse': 1,
#  'uplifted': 1,
#  'SufferingThere': 1,
#  'pain': 1,
#  'Live': 1,
#  'allow': 1,
#  'care': 1,
#  'Lord': 1,
#  'forsake': 1,
#  'eilish': 1,
#  'solo': 1,
#  'reasonable': 1,
#  'thrill': 1,
#  'fairest': 1,
#  'ROUGH': 1,
#  'paediatric': 1,
#  'hospital': 1,
#  'somewhere': 1,
#  'enable': 1,
#  'fullness': 1,
#  'lest': 1,
#  'unforgiveable': 1,
#  'realize': 1,
#  'outside': 1,
#  'todayIn': 1,
#  'ultimate': 1,
#  'forgiveness': 1,
#  'friend': 1,
#  'say': 1,
#  'popular': 1,
#  'lack': 1,
#  'Worship': 1,
#  'video': 1,
#  'younger': 1,
#  'honest': 1,
#  'humbled': 1,
#  'unworthyGod': 1,
#  'tread': 1,
#  'n': 1,
#  'majesty': 1,
#  'begin': 1,
#  'infinite': 1,
#  'End': 1,
#  'Ridiculous': 1,
#  'heaven': 1,
#  'narrow': 1,
#  'Powerful': 1,
#  'optional': 1,
#  'orphan': 1,
#  'unloved': 1,
#  'young': 1,
#  'did': 1,
#  'interpretation': 1,
#  'Jesusstory': 1,
#  'beIn': 1,
#  'talent': 1,
#  'likeness': 1,
#  'Unexpected': 1,
#  'First': 1,
#  'peaceful': 1,
#  'Blessed': 1,
#  'intentional': 1,
#  'prepare': 1,
#  'walk': 1,
#  'saved': 1,
#  'biblical': 1,
#  'speak': 1,
#  'type': 1,
#  'tuesday': 1,
#  'nice': 1,
#  'stop': 1,
#  'house': 1,
#  'cosmic': 1,
#  'disrupt': 1,
#  'enemy': 1,
#  'fry': 1,
#  'black': 1,
#  'moderate': 1,
#  'occupier': 1,
#  'undeserving': 1,
#  'worthiest': 1,
#  'millennial': 1,
#  'discrete': 1,
#  'nod': 1,
#  'toughest': 1,
#  'low': 1,
#  'unborn': 1,
#  'take': 1,
#  'unsaved': 1,
#  'Unbelief': 1,
#  'deliberate': 1,
#  'start': 1,
#  'spite': 1,
#  'acceptable': 1,
#  'laden': 1,
#  'greater': 1,
#  'useful': 1,
#  'confess': 1,
#  'theologian': 1,
#  'caught': 1,
#  'reflect': 1,
#  'puppetthe': 1,
#  'enforce': 1,
#  'progress': 1,
#  'Clean': 1,
#  'till': 1,
#  'bitter': 1,
#  'born': 1,
#  'graceI': 1,
#  'grace': 1,
#  'consist': 1,
#  'Plenty': 1,
#  'similar': 1,
#  'secret': 1,
#  'unseen': 1,
#  'lie': 1,
#  'ok': 1,
#  'People': 1,
#  'nativityPraying': 1,
#  'fine': 1,
#  'successful': 1,
#  'itAgainI': 1,
#  'forgiven': 1,
#  'dis': 1,
#  'boughtYour': 1,
#  'dry': 1,
#  'votesFinal': 1,
#  'call': 1,
#  'illegal': 1,
#  'rangersBrady': 1,
#  'Rm': 1,
#  'limit': 1,
#  'ear': 1,
#  'heard': 1,
#  'generic': 1,
#  'Whole': 1,
#  'fish': 1,
#  'monumental': 1,
#  'encouraging': 1,
#  'hidden': 1,
#  'box': 1,
#  'Read': 1,
#  'vulnerable': 1,
#  'lightning': 1,
#  'muchTHE': 1,
#  'Actual': 1,
#  'lesson': 1,
#  'creative': 1,
#  'imperfect': 1,
#  'world': 1,
#  'todayYou': 1,
#  'temporary': 1,
#  'satanic': 1,
#  'rip': 1,
#  'unclean': 1,
#  'behold': 1,
#  'fam': 1,
#  'adorable': 1,
#  'incomprehensible': 1,
#  'ineffable': 1,
#  'verbal': 1,
#  'priest': 1,
#  'sonAll': 1,
#  'greatYou': 1,
#  'reign': 1,
#  'nail': 1,
#  'loving': 1,
#  'unambiguous': 1,
#  'sedentary': 1,
#  'active': 1,
#  'Stan': 1,
#  'courageous': 1,
#  'united': 1,
#  'Eternal': 1,
#  'flatironschurch': 1,
#  'whatyouwant': 1,
#  'itaintsacreligious': 1,
#  'Rom': 1,
#  'steadfast': 1,
#  'easier': 1,
#  'Free': 1,
#  'secondguessing': 1,
#  'clinical': 1,
#  'scripture': 1,
#  'spreading': 1,
#  'nameChrist': 1,
#  'Racial': 1,
#  'boyfriend': 1,
#  'whats': 1,
#  'discernment': 1,
#  'reject': 1,
#  'Revival': 1,
#  'My': 1,
#  'redemptive': 1,
#  'straight': 1,
#  'scale': 1,
#  'outweigh': 1,
#  'YOU': 1,
#  'himAnd': 1,
#  'American': 1,
#  'enormous': 1,
#  'mess': 1,
#  'messagea': 1,
#  'minute': 1,
#  'look': 1,
#  'beat': 1,
#  'bread': 1,
#  'undeserved': 1,
#  'amazement': 1,
#  'reverenced': 1,
#  'mighty': 1,
#  'weight': 1,
#  'Heartfelt': 1,
#  'cause': 1,
#  'older': 1,
#  'SPEAK': 1,
#  'understands': 1,
#  'whither': 1,
#  'me': 1,
#  'preach': 1,
#  'orthodox': 1,
#  'neglect': 1,
#  'forth': 1,
#  'meHis': 1,
#  'died': 1,
#  'meWho': 1,
#  'street': 1,
#  'evolutionThey': 1,
#  'fairytalesHuman': 1,
#  'atheist': 1,
#  'burial': 1,
#  'aweful': 1,
#  'literal': 1,
#  'pagan': 1,
#  'destiny': 1,
#  'irresistible': 1,
#  'undeniable': 1,
#  'incredible': 1,
#  'blind': 1,
#  'fake': 1,
#  'unconditional': 1,
#  'inclusive': 1,
#  'skin': 1,
#  'medical': 1,
#  'incompatible': 1,
#  'Implant': 1,
#  'broke': 1,
#  'COMING': 1,
#  'miss': 1,
#  'wanted': 1,
#  'represent': 1,
#  'truth': 1,
#  'guideline': 1,
#  'appreciate': 1,
#  'coming': 1,
#  'nathanwagers': 1,
#  'gosh': 1,
#  'sad': 1,
#  'use': 1,
#  'empathy': 1,
#  'tiny': 1,
#  'barren': 1,
#  'endDon': 1,
#  'told': 1,
#  'saviour': 1,
#  'nAJis': 1,
#  'declare': 1,
#  'emotion': 1,
#  'itThank': 1,
#  'mangerNo': 1,
#  'lord': 1,
#  'clock': 1,
#  'flavour': 1,
#  'superior': 1,
#  'proclaim': 1,
#  'spoken': 1,
#  'Be': 1,
#  'smilesBe': 1,
#  'hopefulBe': 1,
#  'lovedBe': 1,
#  'brokenBe': 1,
#  'strength': 1,
#  'stjude': 1,
#  'saintjude': 1,
#  'saintjudethaddeus': 1,
#  'friday': 1,
#  'tgif': 1,
#  'grant': 1,
#  'childish': 1,
#  'closer': 1,
#  'Selfishness': 1,
#  'lighthearted': 1,
#  'companionable': 1,
#  'strive': 1,
#  'inner': 1,
#  'lift': 1,
#  'rid': 1,
#  'soldier': 1,
#  'crown': 1,
#  'head': 1,
#  'arrayed': 1,
#  'struck': 1,
#  'are': 1,
#  'beloved': 1,
#  'worldto': 1,
#  'witness': 1,
#  'voice': 1,
#  'crossshaped': 1,
#  'bring': 1,
#  'profane': 1,
#  'birthright': 1,
#  'mindful': 1,
#  'front': 1,
#  'three': 1,
#  'soon': 1,
#  'Romv': 1,
#  'Ready': 1,
#  'othersau': 1,
#  'abhishekdabur': 1,
#  'Word': 1,
#  'logical': 1,
#  'logic': 1,
#  'rationale': 1,
#  'some': 1,
#  'restore': 1,
#  'obey': 1,
#  'lostmake': 1,
#  'extraordinary': 1,
#  'leather': 1,
#  'earthen': 1,
#  'ye': 1,
#  'erroneous': 1,
#  'LinsonVarughese': 1,
#  'incarnate': 1,
#  'meOne': 1,
#  'men': 1,
#  'lesbian': 1,
#  'earthly': 1,
#  'emotional': 1}

# %%
top_20_adj_dict = dict(itertools.islice(lemmed_adj_sorted_dict.items(), 20))
top_20_adj_df = pd.DataFrame.from_dict(top_20_adj_dict, columns=["BLESS"], orient='index')
# Out:
#                BLESS
# u                123
# good              31
# unto              24
# give              20
# many              18
# new               18
# eternal           17
# great             16
# dead              15
# true              14
# Good              12
# able              11
# hear              11
# much              10
# understanding     10
# last              10
# Christian         10
# better            10
# guard              9
# live               9

# %%
def get_lemmed_sorted_dict(df):
    list_df = reformat_data(df)
    main_df = pd.DataFrame(list_df, columns=["Name", "Date", "Num_comments", "Num_retweets", "Num_likes", "Content"])
    VADER_compound_score_list = []
    for text in main_df["Content"]:
        VADER_compound_score_list.append(analyse(text))
    main_df["VADER_score"] = VADER_compound_score_list
    lemmed_adj_sorted_dict = get_adjectives_dict(main_df, stop_words)
    return lemmed_adj_sorted_dict, main_df

# %%
#full df with duplicates removed
full_df_list = []
for THEME in theme_name_list:
    file_path = "C:/Users/user/OneDrive - Singapore University of Technology and Design/Documents/SUTD/DH/Final Project/data/"
    file_name = f"{THEME}_2018-2020.csv"
    df = pd.read_csv(file_path+file_name)
    df["Theme"] = [THEME for i in range(len(df))]
    full_df_list.append(df)
full_df = pd.concat(full_df_list, axis=0)
#print(len(full_df))
full_df.drop_duplicates(keep="first", inplace=True)
#print(len(full_df))
lemmed_sorted_dict, main_df = get_lemmed_sorted_dict(full_df)

# %%
#top_10_adj_aggregate_dict = dict(itertools.islice(sorted_dict.items(), 20))
above_100_sorted_dict = {}
for key, val in lemmed_sorted_dict.items():
        if lemmed_sorted_dict[key] >= 100:
            above_100_sorted_dict[key] = lemmed_sorted_dict[key]
            
above_100_df = pd.DataFrame.from_dict(above_100_sorted_dict, columns=['Total occurances'], orient='index')
# Out:
#           Total occurances
# u                     2364
# good                   549
# give                   346
# great                  311
# new                    286
# many                   279
# free                   268
# eternal                235
# true                   219
# forgive                218
# live                   196
# much                   196
# human                  195
# unto                   179
# dead                   176
# faith                  167
# full                   158
# Good                   150
# whole                  150
# right                  150
# strong                 146
# best                   141
# last                   139
# real                   130
# safe                   126
# able                   125
# holy                   123
# perfect                116
# powerful               114
# light                  111
# first                  106
# thankful               105

# %%
above_100_df.to_csv(f'above_100_df.csv')

# %%
main_df.sample(10)
#7108
#7204
#10393
#7725
# Out:
#                    Name              Date  \
# 11059          † Sean †      @Saved_Sean_
# 5109        @One_Of_His       Feb 1, 2019
# 2487     @ArefMashaliUK       Jun 28 2020
# 8195          @peero007       Jan 29 2020
# 1683        @rabbicraig       Jan 31 2020
# 8321        @SirMakhubo        Dec 1 2020
# 2267    @Burning___Bush      Jun 30, 2018
# 6795         Ozil's bae            · 2020
# 14841       @LorenaG_82      Jan 31, 2018
# 9991   Beatlemaniac2015  @Beatlemaniac201
#
#                                                                                                                                                                                                           Num_comments  \
# 11059                                                                                                                                                                                                                2
# 5109                                                                                                                                                                                                                 7
# 2487                                                                                                                                                                                                                12
# 8195                                                                                                                                                                                                                 6
# 1683                                                                                                                                                                                                                 7
# 8321                                                                                                                                                                                                                13
# 2267                                                                                                                                                                                                                 2
# 6795                                                                                                                                                                                                                14
# 14841  1\nTheme                                                                                                                                                                                                PROVIDE
# 9991                                                                                                                                                                                                                 1
#
#                                                                                                                                                                                                                                                                                                                                                      Num_retweets  \
# 11059                                                                                                                                                                                                                                                                                                                                                          14
# 5109                                                                                                                                                                                                                                                                                                                                                           53
# 2487                                                                                                                                                                                                                                                                                                                                                           25
# 8195                                                                                                                                                                                                                                                                                                                                                           11
# 1683                                                                                                            22\nTheme                                                                                                                                                                                                                           GOD_SOVEREIGN
# 8321   63\nTheme                                                                                                                                                                                                                                                                                                                                            PEACE
# 2267                                                                                                                                                                                                                                                                                                                                                           27
# 6795                                                                                                                                                                                                                                                                                                                                                            7
# 14841                                                                                                                                                                                                                                                                                                                                                        None
# 9991                                                                                                                                                                                                                                                                                                                                                            4
#
#                                                                                                                                                                                                                                                                                                                                                                                     Num_likes  \
# 11059                                                                                         68\nTheme                                                                                                                                                                                                                                                                                  SAVE
# 5109                             123\nTheme                                                                                                                                                                                                                                                                                                                                              HOPE
# 2487                                                  92\nTheme                                                                                                                                                                                                                                                                                                                         GRACE
# 8195   Show this thread\nTheme                                                                                                                                                                                                                                                                                                                                                          PEACE
# 1683                                                                                                                                                                                                                                                                                                                                                                                     None
# 8321                                                                                                                                                                                                                                                                                                                                                                                     None
# 2267                                    67\nTheme                                                                                                                                                                                                                                                                                                                               GOD_SOVEREIGN
# 6795                                                                                                                    103\nTheme                                                                                                                                                                                                                                                      MERCY
# 14841                                                                                                                                                                                                                                                                                                                                                                                    None
# 9991                                                                                   13\nTheme                                                                                                                                                                                                                                                                                      PROTECT
#
#                                                                                                                                                                                                                                                                                         Content  \
# 11059                                                                               ·Jan 29Jesus is EVERYTHING, you guys.If you don't have a relationship with your Saviour, Jesus Christ, you're missing out.Got Jesus? You got EVERYTHING you need.Don't got Jesus? You got NOTHING you need.
# 5109           1 Thess 4:13-14 KJVBut I would not have you to be ignorant, brethren, concerning them which are asleep, that ye sorrow not, even as others which have no hope. For if we believe that Jesus died and rose again, even so them also which sleep in Jesus will God bring with him.
# 2487                       Holy Father, please soften my heart and toughen my resolve so that I can love as Jesus loved. Make my life redemptive, even to those who oppose, abhor, ridicule, and hate me. Use me, dear Father, to bring others to the grace of Jesus. In his name I pray. Amen.
# 8195   Now may the God of peace, that brought again from the dead our Lord Jesus, that great shepherd of the sheep, through the blood of the everlasting covenant, make us perfect in every good work to do His will, working in us what is well pleasing in His eyes, through Jesus Christ...1
# 1683                                                                                                   Its one thing to know the Sabbath n its another thing to know the Lord of the Sabbath... true sabbath rest is given ONLY by Jesus Christ and fully experienced in Jesus... #happysabbath
# 8321                  00:00. Let's pray Congratulations, you've made it to month 12/12: December God,Thank You for guiding me to yet another month. Now may You bless my December 1-31 with peace, strength, wisdom, opportunities, spiritual, mental & financial expansion.In Jesus name. Amen
# 2267                          Jesus is coming soon! And time is short.If you don't see God working in your life, you need to examine yourself as to whether you are saved and of the faith (2Cor 13:5).We must be honest with ourselves. Where the Spirit of God resides, things are happening.
# 6795                                                                                                        Nov 21A leaf is glorious while on the tree, but the moment it drops, it loses its glory. You will never drop from God's divine grace, mercy, favour and protection in Jesus’ name.
# 14841                                                                                                                                            Lawd Jesus, please give me the strength to stay sober during the train wreck that is about to ensue on national television   #FixItJesus #SOTU
# 9991                                                             ·Jan 27, 2019God and Jesus we pray that you watch over the Men and Women who are out keeping the city safe. Please keep them safe and bring them home to their families. In Jesus Name Amen.  #BackTheBlue #BlueFamilyPrayers
#
#        VADER_score
# 11059      -0.3736
# 5109       -0.7430
# 2487        0.8850
# 8195        0.9477
# 1683        0.4215
# 8321        0.9670
# 2267        0.8055
# 6795        0.9730
# 14841       0.3818
# 9991        0.8555
