# %%
def get_websites(theme_list, date_set):
    start = "https://twitter.com/search?f=live&q=Jesus%20("
    word_input = '%20OR%20'.join(word for word in theme_list)
    middle = ")%20lang%3Aen%20until%3A"
    end = "%20-filter%3Alinks%20-filter%3Areplies&src=typed_query"
    full = start+word_input+middle+date_set[1]+"%20since%3A"+date_set[0]+end
    print(full)

# %%
date_set_list = []
for year in ["2020", "2019", "2018"]:
    for month in [("01", "02"), ("06", "07"), ("11", "12")]:
        fromm = '-'.join(i for i in (year, month[0], "01"))
        to = '-'.join(i for i in (year, month[1], "01"))
        date_set_list.append((fromm, to))

# %%
theme_list = []
theme_list.append(['love', 'loves', 'loved', 'loving', 'care', 'cares', 'caring', 'cared', 'encourage', 'encourages', 'encouraging', 'encouraged'])
theme_list.append(['disciples', 'disciple', 'discipled', 'discipling', 'teaches', 'taught', 'teaching', 'teach', 'preached', 'preaches', 'preach', 'preaching', 'prophet'])
theme_list.append(['knowledge', 'wisdom', 'wise', 'knows', 'knew', 'inspires', 'inspired', 'shepherd', 'guide', 'guides'])
theme_list.append(['blesses', 'blessed', 'blessing', 'gifts', 'gift', 'gifting', 'giftings'])
theme_list.append(['forgives', 'forgive', 'forgave', 'forgiven', 'forgiveness', 'pardoned', 'pardon', 'pardoning', 'pardons'])
theme_list.append(['grace'])
theme_list.append(['mercy', 'merciful', 'lenient', 'leniency', 'lenience', 'compassion', 'charity'])
theme_list.append(['sacrifice', 'sacrificed', 'self-sacrifice', 'self-immolation', 'yield'])
theme_list.append(['king', 'creator', 'author', 'ruler', 'mighty', 'god', 'lord', 'almighty', 'divine', 'celestial', 'supreme', 'divinity', 'immortal', 'godhead', 'sovereign', 'authority'])
theme_list.append(['heir', 'human', 'humanness', 'born', 'son'])
theme_list.append(['heal', 'healed', 'heals', 'healer', 'doctor', 'physician', 'cure', 'curer', 'medicine', 'restore', 'mend', 'curing', 'restorative', 'life-giving', 'health', 'health-giving'])
theme_list.append(['power', 'powerful', 'strong', 'dominant', 'dominate', 'dominates', 'dominating', 'authoritative'])
theme_list.append(['hope', 'hoping', 'hopes', 'hoped', 'wish', 'dream', 'promise', 'confidence', 'faith', 'trust', 'belief', 'desire'])
theme_list.append(['trinity'])
theme_list.append(['righteousness', 'sanctify', 'sanctification', 'consecrate', 'holy', 'sacred', 'hallowed', 'dedicated', 'anoint', 'ordain', 'cleanse', 'purify', 'pure', 'clean', 'absolve', 'intercede', 'interceding'])
theme_list.append(['sees', 'see', 'witness', 'knows', 'notice', 'notices', 'noticed', 'perceive', 'perceives'])
theme_list.append(['protect', 'protects', 'protected', 'protecting', 'safe', 'shield', 'shields', 'shielding', 'defend', 'defends', 'defended', 'defending', 'shelter', 'sheltered', 'shelters', 'secure', 'guard'])
theme_list.append(['peace', 'peacefulness', 'tranquil', 'calm', 'calming', 'calms', 'calmed', 'content'])
theme_list.append(['provide', 'provider', 'provides', 'providing', 'providence', 'supply', 'give', 'dispense', 'bestow', 'impart'])
theme_list.append(['save', 'saves', 'saved', 'saving', 'saviour', 'rescue', 'liberate', 'free', 'deliver', 'delivers', 'deliverer'])
theme_list.append(['overcome', 'overcomer', 'overcame', 'overcomes', 'victor', 'victory', 'victories', 'win', 'winner', 'winning', 'conquer', 'conqueror', 'conquering', 'conquered', 'master', 'mastered', 'beat', 'triumph', 'triumphed', 'triumphs', 'overpower', 'overpowered', 'overpowers', 'prevail', 'prevailed', 'prevails' ])
aggregate_theme_list = []
for theme in theme_list:
    for word in theme:
        aggregate_theme_list.append(word)
#aggregate_theme_list
for date_set in date_set_list:
    get_websites(aggregate_theme_list, date_set)
# Out:
# https://twitter.com/search?f=live&q=Jesus%20(love%20OR%20loves%20OR%20loved%20OR%20loving%20OR%20care%20OR%20cares%20OR%20caring%20OR%20cared%20OR%20encourage%20OR%20encourages%20OR%20encouraging%20OR%20encouraged%20OR%20disciples%20OR%20disciple%20OR%20discipled%20OR%20discipling%20OR%20teaches%20OR%20taught%20OR%20teaching%20OR%20teach%20OR%20preached%20OR%20preaches%20OR%20preach%20OR%20preaching%20OR%20prophet%20OR%20knowledge%20OR%20wisdom%20OR%20wise%20OR%20knows%20OR%20knew%20OR%20inspires%20OR%20inspired%20OR%20shepherd%20OR%20guide%20OR%20guides%20OR%20blesses%20OR%20blessed%20OR%20blessing%20OR%20gifts%20OR%20gift%20OR%20gifting%20OR%20giftings%20OR%20forgives%20OR%20forgive%20OR%20forgave%20OR%20forgiven%20OR%20forgiveness%20OR%20pardoned%20OR%20pardon%20OR%20pardoning%20OR%20pardons%20OR%20grace%20OR%20mercy%20OR%20merciful%20OR%20lenient%20OR%20leniency%20OR%20lenience%20OR%20compassion%20OR%20charity%20OR%20sacrifice%20OR%20sacrificed%20OR%20self-sacrifice%20OR%20self-i
# ...
